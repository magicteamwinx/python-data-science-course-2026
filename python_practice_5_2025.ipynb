# %% [markdown]
# <a href="https://colab.research.google.com/github/magicteamwinx/python-data-science-course-2026/blob/main/python_practice_5_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:


  def __init__(self, name, city, building_type = "public" ):
    self.name = name
    self.city = city
    self.building_type = building_type

  def greet(self):
    print(f"Welcome to {self.name} in {self.city}! Type: {self.building_type}")

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
building1 = Building("Idea Shop", "Kyiv")
print(building1.city)
print(building1.building_type)

building2 = Building("Idea", "Tokyo", "private")
print(building2.building_type)
building2.greet()
# Out:
# Kyiv
# public
# private
# Welcome to Idea in Tokyo! Type: private

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
class Dog:
    def __init__(self, name, age, breed):
        self.__name = name  # Private
        self._breed = breed # Protected
        self.age = age      # Public

    def __str__(self):
        return f"{self.__name} (a {self._breed}) is {self.age} years old."

dog1 = Dog("Buddy", 3, "Beagle")

print(dog1.age)        # ПРАЦЮЄ: виведе 3
print(dog1._breed)     # ПРАЦЮЄ: виведе Beagle
print(dog1.__name__)   # ПОМИЛКА: AttributeError
# Out:
# 3
# Beagle
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2884/1335547470.py in <cell line: 0>()
#      12 print(dog1.age)        # ПРАЦЮЄ: виведе 3
#      13 print(dog1._breed)     # ПРАЦЮЄ: виведе Beagle
# ---> 14 print(dog1.__name__)   # ПОМИЛКА: AttributeError
#
# AttributeError: 'Dog' object has no attribute '__name__'

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# Термін self посилання на поточний екземпляр класу. Метод __init __ дефолтний, використовується для присвоєння значень властивостям об’єкта або для виконання операцій, необхідних під час створення об’єкта.

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
class Model3D:
  def get_volume(self):
    return 0

  def __add__(self, other):
    return self.get_volume() + other.get_volume()

object1 = Model3D()
object2 = Model3D()


total_volume = object1 + object2
print(total_volume)
# Out:
# 0

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
import math

class Cylinder(Model3D):
   def __init__(self, radius, height):
        self.radius = radius
        self.height = height
   def get_volume(self):
        # π * r² * h
        return math.pi * (self.radius ** 2) * self.height

class Cube(Model3D):
   def __init__(self, side):
        self.side = side
   def get_volume(self):
        return self.side ** 3

my_cube = Cube(3)
my_cylinder = Cylinder(2, 5)

total = my_cube + my_cylinder

print(f"Cube volume: {my_cube.get_volume()}")
print(f"Cylinder volume: {my_cylinder.get_volume():.2f}")
print(f"Total volume: {total:.2f}")
# Out:
# Cube volume: 27
# Cylinder volume: 62.83
# Total volume: 89.83

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
class Model3D:
    pass

class Cube(Model3D):
    pass

# Створюємо об'єкт (екземпляр)
my_cube = Cube()

# --- Перевірка через isinstance ---
print(isinstance(my_cube, Cube))    # True (my_cube — це куб)
print(isinstance(my_cube, Model3D)) # True (куб також є 3D-моделлю)
print(isinstance(Cube, Model3D))    # False! (Клас Cube сам по собі не є об'єктом Model3D)

# --- Перевірка через issubclass ---
print(issubclass(Cube, Model3D))    # True (Клас Cube успадковує Model3D)
print(issubclass(Model3D, Cube))    # False (Батько не є нащадком дитини)
# print(issubclass(my_cube, Cube))  # Викличе помилку TypeError!
                                    # (my_cube — це об'єкт, а не клас)
# Out:
# True
# True
# False
# True
# False

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class EWallet:
    def __init__(self, wallet_id, initial_balance=0.0):
        # Приватні атрибути з подвійним підкресленням
        self.__id = wallet_id
        self.__balance = float(initial_balance)

    # Геттер для ID (тільки для читання, без сеттера)
    @property
    def wallet_id(self):
        return self.__id

    # Геттер для балансу
    @property
    def balance(self):
        return self.__balance

    # Сеттер для балансу (контролює логіку зміни)
    @balance.setter
    def balance(self, value):
        if value < 0:
            print("Помилка: Баланс не може бути від'ємним!")
        else:
            self.__balance = value

    # Метод для поповнення
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount  # Використовує сеттер
            print(f"Поповнено на {amount}. Поточний баланс: {self.balance}")
        else:
            print("Сума поповнення має бути додатною!")

    # Метод для зняття
    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount  # Використовує сеттер
            print(f"Знято {amount}. Поточний баланс: {self.balance}")
        elif amount > self.balance:
            print("Недостатньо коштів на рахунку!")
        else:
            print("Сума зняття має бути додатною!")

# --- Демонстрація роботи ---
my_wallet = EWallet("UA-777", 100)

print(f"Гаманець: {my_wallet.wallet_id}") # Звертаємось як до атрибута
my_wallet.deposit(50)                    # Поповнюємо
my_wallet.withdraw(30)                   # Знімаємо
my_wallet.balance = -500                 # Спроба прямого запису через сеттер (спрацює перевірка)
# Out:
# Гаманець: UA-777
# Поповнено на 50. Поточний баланс: 150.0
# Знято 30. Поточний баланс: 120.0
# Помилка: Баланс не може бути від'ємним!

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class Item:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"{self.name}: {self.price} грн"


class ShoppingCart:
    def __init__(self):
        # Список для зберігання об'єктів типу Item
        self.items = []

    def add_item(self, item):
        """Додає об'єкт Item до кошика"""
        if isinstance(item, Item):
            self.items.append(item)
            print(f"Додано: {item.name}")
        else:
            print("Помилка: Можна додавати лише об'єкти класу Item")

    def remove_item(self, item_name):
        """Видаляє айтем з кошика за його назвою"""
        for item in self.items:
            if item.name == item_name:
                self.items.remove(item)
                print(f"Видалено: {item_name}")
                return
        print(f"Товар '{item_name}' не знайдено в кошику")

    def show_cart(self):
        """Відображає всі товари в кошику та загальну вартість"""
        if not self.items:
            print("Кошик порожній.")
            return

        print("\n--- Ваш кошик ---")
        total_price = 0
        for item in self.items:
            print(f"- {item}")
            total_price += item.price
        print(f"Загальна сума: {total_price} грн\n")


# --- Демонстрація роботи ---

# Створюємо товари
apple = Item("Яблуко", 15)
milk = Item("Молоко", 40)
bread = Item("Хліб", 25)

# Створюємо кошик
my_cart = ShoppingCart()

# Додаємо товари
my_cart.add_item(apple)
my_cart.add_item(milk)
my_cart.add_item(bread)

# Показуємо вміст
my_cart.show_cart()

# Видаляємо один товар
my_cart.remove_item("Молоко")

# Фінальний список
my_cart.show_cart()
# Out:
# Додано: Яблуко
# Додано: Молоко
# Додано: Хліб
#
# --- Ваш кошик ---
# - Яблуко: 15 грн
# - Молоко: 40 грн
# - Хліб: 25 грн
# Загальна сума: 80 грн
#
# Видалено: Молоко
#
# --- Ваш кошик ---
# - Яблуко: 15 грн
# - Хліб: 25 грн
# Загальна сума: 40 грн

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
class Vehicle:
    def __init__(self, brand, production_age):
        self.brand = brand
        self.production_age = production_age

    def display_vehicle_info(self):
        print(f"Brand: {self.brand}, Age: {self.production_age} years")

class Engine:
    def __init__(self, engine_type, size):
        self.engine_type = engine_type
        self.size = size

    def display_engine_info(self):
        print(f"Engine: {self.engine_type}, Volume: {self.size}L")

# Клас Car успадковує обидва класи одночасно
class Car(Vehicle, Engine):
    def __init__(self, brand, production_age, engine_type, size):
        # Ініціалізуємо обидва батьківські класи
        Vehicle.__init__(self, brand, production_age)
        Engine.__init__(self, engine_type, size)

    def drive(self):
        print(f"The {self.brand} is driving with its {self.size}L engine!")

# --- Демонстрація ---

# Створюємо об'єкт класу Car
my_car = Car("BMW", 3, "petrol", 2.0)

# Використовуємо методи обох батьківських класів
my_car.display_vehicle_info()
my_car.display_engine_info()
my_car.drive()

# Отримуємо MRO (Method Resolution Order)
print("\nMethod Resolution Order (MRO) для класу Car:")
for cls in Car.mro():
    print(cls)
# Out:
# Brand: BMW, Age: 3 years
# Engine: petrol, Volume: 2.0L
# The BMW is driving with its 2.0L engine!
#
# Method Resolution Order (MRO) для класу Car:
# <class '__main__.Car'>
# <class '__main__.Vehicle'>
# <class '__main__.Engine'>
# <class 'object'>

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
my_string = "Pyth"
my_iterator = iter(my_string)

print(next(my_iterator))  # Виведе 'P'
print(next(next_iterator))  # Виведе 'y'
print(next(my_iterator))  # Виведе 't'
print(next(my_iterator))  # Виведе 'h'

next(my_iterator)
# Out:
# P
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2159/3410987444.py in <cell line: 0>()
#       3
#       4 print(next(my_iterator))  # Виведе 'P'
# ----> 5 print(next(next_iterator))  # Виведе 'y'
#       6 print(next(my_iterator))  # Виведе 't'
#       7 print(next(my_iterator))  # Виведе 'h'
#
# NameError: name 'next_iterator' is not defined

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %%
my_string = "Pyth"
next(my_string)  # Помилка! TypeError: 'str' object is not an iterator
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2159/2400056254.py in <cell line: 0>()
#       1 my_string = "Pyth"
# ----> 2 next(my_string)  # Помилка! TypeError: 'str' object is not an iterator
#
# TypeError: 'str' object is not an iterator

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# Ітерабельний об'єкт — це "сховище" даних (як книга), яке можна перебирати, а ітератор — це "покажчик" (як закладка), який пам'ятає поточну позицію і знає, як дістати наступний елемент за запитом.
#
# ---
# # 1. Ітерабельний об'єкт (Iterable) — це "сховище"
# my_list = [10, 20, 30]
#
# # 2. Ітератор (Iterator) — це "покажчик", який ми створюємо з цього сховища
# my_iterator = iter(my_list)
#
# # Тепер ми можемо рухати "покажчик" далі
# print(next(my_iterator))  # Виведе 10
# print(next(my_iterator))  # Виведе 20

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class WeekIterator:
    def __init__(self):
        self.days = [
            "Понеділок", "Вівторок", "Середа",
            "Четвер", "Пʼятниця", "Субота", "Неділя"
        ]
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index < len(self.days):
            day = self.days[self.index]
            self.index += 1
            return day
        else:
            raise StopIteration


week = WeekIterator()

for day in week:
    print(day)

another_week = WeekIterator()
print(f"\nПерший день: {next(another_week)}")
# Out:
# Понеділок
# Вівторок
# Середа
# Четвер
# Пʼятниця
# Субота
# Неділя
#
# Перший день: Понеділок

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
